# %% [markdown]
# ##Testing Parapineal Ablation Data on a new Ipython notebook based Thunder script

# %% [markdown]
# ###1. Load Libraries and set up matplotlib

# %%
#Matplotlib plots to be inline in the notebook
# %matplotlib inline

# %%
#Import Python libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
sns.set_style('darkgrid')
sns.set_context('notebook')

# %%
#Import Thunder libraries
from thunder import Colorize
image = Colorize.image

# %% [markdown]
# ####Define some functions:

# %%
def PlotImagePlanes(img):
    # Plot planes in the first image
    numz = np.size(img,2)
    num_subplots = int((math.ceil(numz / 2.) * 2)/2)

    fig1 = plt.figure(figsize=(10,5))
    for ii in xrange(0, numz):    
        ax1 = fig1.add_subplot(num_subplots,2,ii+1)
        ax1 = image(img[:,:,ii])    
        plt.title('Plane: ' + str(ii+1), fontsize=12)
    plt.show()

# %% [markdown]
# ###2. Load Images from Folder using Thunder Context

# %%
#Provide Folder from which to get data
foldername = '/Users/seetha/Desktop/Parapineal_Ablation/Data/01_Zoom=2/Tiff/Sorted/Red_First/Fish1159/Block2/'
data = tsc.loadImages(foldername, inputFormat='tif')

# %%
# Get the first image in data and plot
img = data.first()[1]
PlotImagePlanes(img)

# %%
# Print some info on the data
print 'Shape of first image: ' + str(np.shape(img))
print 'Number of dimensions of data ' + str(data.dims)
print 'Total number of time points ' + str(data.nrecords)
# Out:
# Shape of first image: (256, 512, 5)
# Number of dimensions of data min=(0, 0, 0), max=(255, 511, 4), count=(256, 512, 5)
# Total number of time points 285

# %%
# Looking at images with paricular indices and plot
index = 28
img = data[index]
PlotImagePlanes(img)
print 'Shape of image number '+ str(index) + ' : '+ str(np.shape(img))
# Out:
# Shape of image number 28 : (256, 512, 5)

# %%
# Plot maximum projections and standard deviation
projs = data.maxProjection(axis=2)
img = projs[index]
fig1 = plt.figure(figsize=(5,5))
image(img)

# %%
img = data.stdev()
PlotImagePlanes(img)
# Out:
# Traceback (most recent call last):
#   File "/Users/seetha/anaconda/lib/python2.7/SocketServer.py", line 295, in _handle_request_noblock
# ERROR:py4j.java_gateway:Error while sending or receiving.
# Traceback (most recent call last):
#   File "/Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py", line 479, in send_command
#     raise Py4JError("Answer from Java side is empty")
# Py4JError: Answer from Java side is empty
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server
# Traceback (most recent call last):
#   File "/Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py", line 425, in start
#     self.socket.connect((self.address, self.port))
#   File "/Users/seetha/anaconda/lib/python2.7/socket.py", line 228, in meth
#     return getattr(self._sock,name)(*args)
# error: [Errno 61] Connection refused
#     self.process_request(request, client_address)
#   File "/Users/seetha/anaconda/lib/python2.7/SocketServer.py", line 321, in process_request
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 62503)
#     self.finish_request(request, client_address)
#   File "/Users/seetha/anaconda/lib/python2.7/SocketServer.py", line 334, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/Users/seetha/anaconda/lib/python2.7/SocketServer.py", line 655, in __init__
#     self.handle()
#   File "/Users/seetha/spark-1.4.1-bin-hadoop1/python/pyspark/accumulators.py", line 235, in handle
#     num_updates = read_int(self.rfile)
#   File "/Users/seetha/spark-1.4.1-bin-hadoop1/python/pyspark/serializers.py", line 544, in read_int
# ERROR:py4j.java_gateway:An error occurred while trying to connect to the Java server
# Traceback (most recent call last):
#   File "/Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py", line 425, in start
#     self.socket.connect((self.address, self.port))
#   File "/Users/seetha/anaconda/lib/python2.7/socket.py", line 228, in meth
#     return getattr(self._sock,name)(*args)
# error: [Errno 61] Connection refused
# ----------------------------------------
#     raise EOFError
# EOFError
# ---------------------------------------------------------------------------
# Py4JNetworkError                          Traceback (most recent call last)
# /Users/seetha/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_code(self, code_obj, result)
#    3050             if result is not None:
#    3051                 result.error_in_exec = sys.exc_info()[1]
# -> 3052             self.showtraceback()
#    3053         else:
#    3054             outflag = 0
#
# /Users/seetha/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in showtraceback(self, exc_tuple, filename, tb_offset, exception_only)
#    1851                                             value, tb, tb_offset=tb_offset)
#    1852
# -> 1853                     self._showtraceback(etype, value, stb)
#    1854                     if self.call_pdb:
#    1855                         # drop into debugger
#
# /Users/seetha/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/zmqshell.pyc in _showtraceback(self, etype, evalue, stb)
#     423             u'traceback' : stb,
#     424             u'ename' : unicode_type(etype.__name__),
# --> 425             u'evalue' : py3compat.safe_unicode(evalue),
#     426         }
#     427
#
# /Users/seetha/anaconda/lib/python2.7/site-packages/IPython/utils/py3compat.pyc in safe_unicode(e)
#      60     """
#      61     try:
# ---> 62         return unicode_type(e)
#      63     except UnicodeError:
#      64         pass
#
# /Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/protocol.py in __str__(self)
#     380     def __str__(self):
#     381         gateway_client = self.java_exception._gateway_client
# --> 382         answer = gateway_client.send_command(self.exception_cmd)
#     383         return_value = get_return_value(answer, gateway_client, None, None)
#     384         return '{0}: {1}'.format(self.errmsg, return_value)
#
# /Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in send_command(self, command, retry)
#     360          the Py4J protocol.
#     361         """
# --> 362         connection = self._get_connection()
#     363         try:
#     364             response = connection.send_command(command)
#
# /Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in _get_connection(self)
#     316             connection = self.deque.pop()
#     317         except Exception:
# --> 318             connection = self._create_connection()
#     319         return connection
#     320
#
# /Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in _create_connection(self)
#     323         connection = GatewayConnection(self.address, self.port,
#     324                 self.auto_close, self.gateway_property)
# --> 325         connection.start()
#     326         return connection
#     327
#
# /Users/seetha/spark-1.4.1-bin-hadoop1/python/lib/py4j-0.8.2.1-src.zip/py4j/java_gateway.py in start(self)
#     430                 'server'
#     431             logger.exception(msg)
# --> 432             raise Py4JNetworkError(msg)
#     433
#     434     def close(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server
